# %%
import pandas as pd
import numpy as np
import glob

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, log_loss

# %%
files = glob.glob (r"D:/output_England/*.csv")
print("Found files:", len(files), files[:3])
df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
# Out:
# Found files: 2 ['D:/output_England\\Premier League-2022.csv', 'D:/output_England\\Premier League-2023.csv']

# %%
df
# Out:
#                     date       id      referee       home_team  \
# 0    2022-08-05 19:00:00   867946    A. Taylor  Crystal Palace
# 1    2022-08-06 11:30:00   867947    A. Madley          Fulham
# 2    2022-08-06 14:00:00   867951    S. Hooper       Newcastle
# 3    2022-08-06 14:00:00   867948    P. Bankes     Bournemouth
# 4    2022-08-06 14:00:00   867952  A. Marriner       Tottenham
# ..                   ...      ...          ...             ...
# 755  2024-05-19 15:00:00  1035547     G. Scott         Burnley
# 756  2024-05-19 15:00:00  1035544    M. Oliver         Arsenal
# 757  2024-05-19 15:00:00  1035550  C. Kavanagh       Liverpool
# 758  2024-05-19 15:00:00  1035548    A. Taylor         Chelsea
# 759  2024-05-19 15:00:00  1035551   M. Donohue           Luton
#
#              away_team  home_goals  away_goals result
# 0              Arsenal           0           2   away
# 1            Liverpool           2           2   draw
# 2    Nottingham Forest           2           0   home
# 3          Aston Villa           2           0   home
# 4          Southampton           4           1   home
# ..                 ...         ...         ...    ...
# 755  Nottingham Forest           1           2   away
# 756            Everton           2           1   home
# 757             Wolves           2           0   home
# 758        Bournemouth           2           1   home
# 759             Fulham           2           4   away
#
# [760 rows x 8 columns]
